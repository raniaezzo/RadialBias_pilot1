# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits import mplot3d
from sklearn import linear_model, datasets
import seaborn as sns
import itertools

# %matplotlib inline
sns.set()
#plt.style.use('seaborn-white')

# %%
def multivariate_gaussian_pdf(X,MU,SIGMA):
    '''Returns the pdf of a nultivariate gaussian distribution
     - X, MU are p x 1 vectors
     - SIGMA is a p x p matrix'''
    #Initialize and reshape
    X = X.reshape(-1,1)
    MU = MU.reshape(-1,1)
    p,_ = SIGMA.shape

    #Compute values
    SIGMA_inv = np.linalg.inv(SIGMA)
    denominator = np.sqrt((2 * np.pi)**p * np.linalg.det(SIGMA))
    exponent = -(1/2) * ((X - MU).T @ SIGMA_inv @ (X - MU))
    
    #Return result
    return float((1. / denominator) * np.exp(exponent) )   

def calculate_boundary(X,MU_k,MU_l, SIGMA,pi_k,pi_l): 
    return (np.log(pi_k / pi_l) - 1/2 * (MU_k + MU_l).T @ np.linalg.inv(SIGMA)@(MU_k - MU_l) + X.T @ np.linalg.inv(SIGMA)@ (MU_k - MU_l)).flatten()[0]   


def LDA_score(X,MU_k,SIGMA,pi_k): 
    #Returns the value of the linear discriminant score function for a given class "k" and 
    # a given x value X
    return (np.log(pi_k) - 1/2 * (MU_k).T @ np.linalg.inv(SIGMA)@(MU_k) + X.T @ np.linalg.inv(SIGMA)@ (MU_k)).flatten()[0]   

def predict_LDA_class(X,MU_list,SIGMA,pi_list): 
    #Returns the class for which the the linear discriminant score function is largest
    scores_list = []
    classes = len(MU_list)
    
    for p in range(classes):
        score = LDA_score(X.reshape(-1,1),MU_list[p].reshape(-1,1),sigma,pi_list[0]) 
        scores_list.append(score)
             
    return np.argmax(scores_list)

def QDA_score(X,MU_k,SIGMA,pi_k): 
    #Returns the value of the linear discriminant score function for a given class "k" and 
    # a given x value X
    
    SIGMA_inv = np.linalg.inv(SIGMA)
    result = (np.log(pi_k) - 1/2 * np.log(np.linalg.det(SIGMA_inv)) - 1/2 * (X - MU_k).T @ SIGMA_inv @ (X - MU_k)).flatten()[0] 
    print('log(pi_k)-0.5(det(inverse_sig))')
    print(np.log(pi_k) - 1/2 * np.log(np.linalg.det(SIGMA_inv)))
    print('(X - MU_k).T @ SIGMA_inv @ (X - MU_k)')
    print((X - MU_k).T @ SIGMA_inv @ (X - MU_k))
    print('Before @')
    print(np.log(pi_k) - 1/2 * np.log(np.linalg.det(SIGMA_inv)) - 1/2 * (X - MU_k).T)
    print('After first @')
    print((np.log(pi_k) - 1/2 * np.log(np.linalg.det(SIGMA_inv)) - 1/2 * (X - MU_k).T @ SIGMA_inv))
    print('After second @')
    print((X - MU_k))
    print('before flattening')
    print((np.log(pi_k) - 1/2 * np.log(np.linalg.det(SIGMA_inv)) - 1/2 * (X - MU_k).T @ SIGMA_inv @ (X - MU_k)))
    
    
    return (np.log(pi_k) - 1/2 * np.log(np.linalg.det(SIGMA_inv)) - 1/2 * (X - MU_k).T @ SIGMA_inv @ (X - MU_k)).flatten()[0]   

def predict_QDA_class(X,MU_list,SIGMA_list,pi_list): 
    #Returns the class for which the the linear discriminant score function is largest
    scores_list = []
    classes = len(MU_list)
    
    for p in range(classes):
        score = QDA_score(X.reshape(-1,1),MU_list[p].reshape(-1,1),SIGMA_list[p],pi_list[p]) 
        scores_list.append(score)
             
    return np.argmax(scores_list)

# %%
#iris = sns.load_dataset("iris")
#sns.pairplot(iris, hue="species")

# %%
iris = iris.rename(index = str, columns = {'sepal_length':'1_sepal_length','sepal_width':'2_sepal_width', 'petal_length':'3_petal_length', 'petal_width':'4_petal_width'})
sns.FacetGrid(iris, hue="species", size=6) .map(plt.scatter,"1_sepal_length", "2_sepal_width", )  .add_legend()
plt.title('Scatter plot')
df1 = iris[["1_sepal_length", "2_sepal_width",'species']]
# Out:
# /Users/rania/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Estimating the parameters
mu_list = np.split(df1.groupby('species').mean().values,[1,2])
sigma_list = np.split(df1.groupby('species').cov().values,[2,4], axis = 0)
pi_list = df1.iloc[:,2].value_counts().values / len(df1)

# Our 2-dimensional distribution will be over variables X and Y
N = 100
X = np.linspace(3, 8, N)
Y = np.linspace(1.5, 5, N)
X, Y = np.meshgrid(X, Y)

#fig = plt.figure(figsize = (10,10))
#ax = fig.gca()
color_list = ['Blues','Greens','Reds']
my_norm = colors.Normalize(vmin=-1.,vmax=1.)

g = sns.FacetGrid(iris, hue="species", size=10, palette = 'colorblind') .map(plt.scatter, "1_sepal_length", "2_sepal_width",)  .add_legend()
my_ax = g.ax

for i in range(3):
    mu = mu_list[i]
    Sigma = sigma_list[i]

#Computing the cost function for each theta combination
    zz = np.array(  [multivariate_gaussian_pdf( np.array([xx,yy]).reshape(-1,1), mu, Sigma) 
                     for xx, yy in zip(np.ravel(X), np.ravel(Y)) ] )
#Reshaping the cost values    
    Z = zz.reshape(X.shape)
    Zm = np.ma.masked_array(Z, Z < 0.15)

#Plot the result in 3D
    my_ax.contour( X, Y, Z, 15, alpha = .3 ,cmap = color_list[i], norm = my_norm)
    my_ax.pcolor(X,Y,Zm, alpha = .1, cmap = color_list[i], norm = my_norm)


# Adjust the limits, ticks and view angle
my_ax.set_xlabel('X')
my_ax.set_ylabel('Y')
my_ax.set_title('Multivariate Gaussians with different Sigma ')

plt.show()
# Out:
# /Users/rania/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <ipython-input-5-444c4fbc7157>:33: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   my_ax.pcolor(X,Y,Zm, alpha = .1, cmap = color_list[i], norm = my_norm)

# %%
#Estimating the parameters
mu_list = np.split(df1.groupby('species').mean().values,[1,2])
sigma_list = np.split(df1.groupby('species').cov().values,[2,4], axis = 0)
pi_list = df1.iloc[:,2].value_counts().values / len(df1)

# Our 2-dimensional distribution will be over variables X and Y
N = 200
X = np.linspace(4, 8, N)
Y = np.linspace(1.5, 5, N)
X, Y = np.meshgrid(X, Y)

#fig = plt.figure(figsize = (10,10))
#ax = fig.gca()
color_list = ['Blues','Greens','Reds']
my_norm = colors.Normalize(vmin=-1.,vmax=1.)

g = sns.FacetGrid(iris, hue="species", size=10, palette = 'colorblind') .map(plt.scatter, "1_sepal_length", "2_sepal_width",)  .add_legend()
my_ax = g.ax


#Computing the predicted class function for each value on the grid
zz = np.array(  [predict_QDA_class( np.array([xx,yy]).reshape(-1,1), mu_list, sigma_list, pi_list) 
                     for xx, yy in zip(np.ravel(X), np.ravel(Y)) ] )
    
#Reshaping the predicted class into the meshgrid shape
Z = zz.reshape(X.shape)


#Plot the filled and boundary contours
my_ax.contourf( X, Y, Z, 2, alpha = .1, colors = ('blue','green','red'))
my_ax.contour( X, Y, Z, 2, alpha = 1, colors = ('blue','green','red'))

# Addd axis and title
my_ax.set_xlabel('X')
my_ax.set_ylabel('Y')
my_ax.set_title('QDA and boundaries')

plt.show()
# Out:
# /Users/rania/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Numpy accuracy
#Shape training data
X_data = df1.iloc[:,0:2]
y_labels = df1.iloc[:,2].replace({'setosa':0,'versicolor':1,'virginica':2}).copy()

y_pred = np.array(  [predict_QDA_class( np.array([xx,yy]).reshape(-1,1), mu_list, sigma_list, pi_list) 
                     for xx, yy in zip(np.ravel(X_data.values[:,0]), np.ravel(X_data.values[:,1])) ] )
display(np.mean(y_pred == y_labels))

#predict_QDA_class( np.array([xx,yy]).reshape(-1,1), mu_list, sigma_list, pi_list) 

#Sklearn accuracy
#display(qda.score(X_data,y_labels))
# Out:
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.55918006 -3.54818006]]
# After first @
# [[-3.90941585 -3.48843255]]
# After second @
# [[0.094]
#  [0.072]]
# before flattening
# [[-3.54781041]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.66281805 -3.44581805]]
# After first @
# [[  0.72609885 -10.0808328 ]]
# After second @
# [[-0.836]
#  [ 0.73 ]]
# before flattening
# [[-11.37341135]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.05628577 -3.06328577]]
# After first @
# [[ 0.26746479 -8.09471558]]
# After second @
# [[-1.488]
#  [ 0.526]]
# before flattening
# [[-10.14996868]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.45918006 -3.29818006]]
# After first @
# [[-5.21226769 -0.84896764]]
# After second @
# [[-0.106]
#  [-0.428]]
# before flattening
# [[-4.47182569]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.56281805 -3.19581805]]
# After first @
# [[ 0.12286065 -7.02012477]]
# After second @
# [[-1.036]
#  [ 0.23 ]]
# before flattening
# [[-7.30586974]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-1.95628577 -2.81328577]]
# After first @
# [[-0.1245893  -5.33751348]]
# After second @
# [[-1.688]
#  [ 0.026]]
# before flattening
# [[-7.38282933]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.35918006 -3.39818006]]
# After first @
# [[-2.17951642 -3.63899485]]
# After second @
# [[-0.306]
#  [-0.228]]
# before flattening
# [[-3.89106136]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.46281805 -3.29581805]]
# After first @
# [[ 1.09051494 -8.87276498]]
# After second @
# [[-1.236]
#  [ 0.43 ]]
# before flattening
# [[-10.72712281]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-1.85628577 -2.91328577]]
# After first @
# [[ 0.46998946 -6.83504746]]
# After second @
# [[-1.888]
#  [ 0.226]]
# before flattening
# [[-9.88642155]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.30918006 -3.34818006]]
# After first @
# [[-1.90188454 -3.48272499]]
# After second @
# [[-0.406]
#  [-0.328]]
# before flattening
# [[-4.17562131]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.41281805 -3.24581805]]
# After first @
# [[ 1.12551566 -8.3952713 ]]
# After second @
# [[-1.336]
#  [ 0.33 ]]
# before flattening
# [[-10.45424946]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-1.80628577 -2.86328577]]
# After first @
# [[ 0.48538374 -6.36817557]]
# After second @
# [[-1.988]
#  [ 0.126]]
# before flattening
# [[-9.78175087]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.50918006 -3.59818006]]
# After first @
# [[-2.39304021 -4.88344615]]
# After second @
# [[-0.006]
#  [ 0.172]]
# before flattening
# [[-3.75475267]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.61281805 -3
]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.55918006 -3.54818006]]
# After first @
# [[-3.90941585 -3.48843255]]
# After second @
# [[0.094]
#  [0.072]]
# before flattening
# [[-3.54781041]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.66281805 -3.44581805]]
# After first @
# [[  0.72609885 -10.0808328 ]]
# After second @
# [[-0.836]
#  [ 0.73 ]]
# before flattening
# [[-11.37341135]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.05628577 -3.06328577]]
# After first @
# [[ 0.26746479 -8.09471558]]
# After second @
# [[-1.488]
#  [ 0.526]]
# before flattening
# [[-10.14996868]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.85918006 -3.69818006]]
# After first @
# [[-7.4333228 -2.0991265]]
# After second @
# [[0.694]
#  [0.372]]
# before flattening
# [[-5.7077972]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.96281805 -3.59581805]]
# After first @
# [[ -0.1571451 -10.8400742]]
# After second @
# [[-0.236]
#  [ 1.03 ]]
# before flattening
# [[-11.7628387]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.35628577 -3.21328577]]
# After first @
# [[-0.24774354 -9.07248859]]
# After second @
# [[-0.888]
#  [ 0.826]]
# before flattening
# [[-10.2477828]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.55918006 -3.69818006]]
# After first @
# [[-2.05130023 -5.81535774]]
# After second @
# [[0.094]
#  [0.372]]
# before flattening
# [[-4.23163945]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.66281805 -3.59581805]]
# After first @
# [[  1.39933848 -12.18655347]]
# After second @
# [[-0.836]
#  [ 1.03 ]]
# before flattening
# [[-16.2051364]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.05628577 -3.21328577]]
# After first @
# [[ 0.69030744 -9.91817389]]
# After second @
# [[-1.488]
#  [ 0.826]]
# before flattening
# [[-13.87366406]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.70918006 -3.49818006]]
# After first @
# [[-7.21979901 -0.8546752 ]]
# After second @
# [[ 0.394]
#  [-0.028]]
# before flattening
# [[-5.04739206]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.81281805 -3.39581805]]
# After first @
# [[-0.27655615 -8.70568628]]
# After second @
# [[-0.536]
#  [ 0.63 ]]
# before flattening
# [[-8.12756941]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.20628577 -3.01328577]]
# After first @
# [[-0.34250825 -7.06405348]]
# After second @
# [[-1.188]
#  [ 0.426]]
# before flattening
# [[-7.53649051]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.55918006 -3.64818006]]
# After first @
# [[-2.6706721  -5.03971601]]
# After second @
# [[0.094]
#  [0.272]]
# before flattening
# [[-3.84856809]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.66281805 -3.54581805]]
# After first @
# [[  1.17492527 -11.48464658]]
# After second @
# [[-0.836]
#  [ 0.93 ]]
# before flattening
# [[-14.45418001]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.05628577 -3.16328577]]
# After first @
# [[ 0.54935989 -9.31035445]]
# After second @
# [[-1.488]
#  [ 0.726]]
# before flattening
# [[-12.51086838]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.30918006 -3.59818006]]
# After first @
# [[ 1.19497483 -7.36093365]]
# After second @
# [[-0.406]
#  [ 0.172]]
# before flattening
# [[-6.08527057]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.41281805 -3.49581805]]
# After first @
# [[  2.24758171 -11.90480575]]
# After second @
# [[-1.336]
#  [ 0.83 ]]
# before flattening
# [[-17.52346993]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-1.80628577 -3.11328577]]
# After first @
# [[ 1.1901215  -9.40727277]]
# After second @
# [[-1.988]
#  [ 0.626]]
# before flattening
# [[-14.86918927]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.55918006 -3.44818006]]
# After first @
# [[-5.1481596  -1.93714909]]
# After second @
# [[ 0.094]
#  [-0.128]]
# before flattening
# [[-3.8675661]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.66281805 -3.34581805]]
# After first @
# [[ 0.27727243 -8.67701902]]
# After second @
# [[-0.836]
#  [ 0.53 ]]
# before flattening
# [[-8.85416821]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.05628577 
]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.31281805 -3.14581805]]
# After first @
# [[-3.99276152 -2.95201971]]
# After second @
# [[0.464]
#  [0.13 ]]
# before flattening
# [[-3.48721604]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.70628577 -2.76328577]]
# After first @
# [[-2.61066432 -2.61548078]]
# After second @
# [[-0.188]
#  [-0.074]]
# before flattening
# [[-2.84961017]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.30918006 -3.29818006]]
# After first @
# [[-20.46133164   9.68035421]]
# After second @
# [[ 1.594]
#  [-0.428]]
# before flattening
# [[-36.17553234]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.41281805 -3.19581805]]
# After first @
# [[-4.28717617 -3.20510018]]
# After second @
# [[0.664]
#  [0.23 ]]
# before flattening
# [[-3.91042473]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.80628577 -2.81328577]]
# After first @
# [[-2.78240043 -2.94140512]]
# After second @
# [[0.012]
#  [0.026]]
# before flattening
# [[-2.80374025]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.40918006 -3.19818006]]
# After first @
# [[-23.4940829   12.47038142]]
# After second @
# [[ 1.794]
#  [-0.628]]
# before flattening
# [[-49.39676237]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.51281805 -3.09581805]]
# After first @
# [[-5.25483045 -1.35245997]]
# After second @
# [[0.864]
#  [0.03 ]]
# before flattening
# [[-4.90731402]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.90628577 -2.71328577]]
# After first @
# [[-3.37697919 -1.44387114]]
# After second @
# [[ 0.212]
#  [-0.174]]
# before flattening
# [[-3.15856092]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.35918006 -3.29818006]]
# After first @
# [[-21.3583354   10.29972608]]
# After second @
# [[ 1.694]
#  [-0.428]]
# before flattening
# [[-39.65506303]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.46281805 -3.19581805]]
# After first @
# [[-4.5465901  -2.98068697]]
# After second @
# [[0.764]
#  [0.23 ]]
# before flattening
# [[-4.17763774]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.85628577 -2.81328577]]
# After first @
# [[-2.93874226 -2.80045757]]
# After second @
# [[0.112]
#  [0.026]]
# before flattening
# [[-2.81579736]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.00918006 -3.24818006]]
# After first @
# [[-15.69868094   6.7397647 ]]
# After second @
# [[ 0.994]
#  [-0.528]]
# before flattening
# [[-21.03858877]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.11281805 -3.14581805]]
# After first @
# [[-2.95510579 -3.84967256]]
# After second @
# [[0.064]
#  [0.13 ]]
# before flattening
# [[-3.17272355]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.50628577 -2.76328577]]
# After first @
# [[-1.98529699 -3.17927098]]
# After second @
# [[-0.588]
#  [-0.074]]
# before flattening
# [[-3.25145427]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.85918006 -3.09818006]]
# After first @
# [[-14.86578528   7.20857427]]
# After second @
# [[ 0.694]
#  [-0.828]]
# before flattening
# [[-20.26836667]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-2.96281805 -2.99581805]]
# After first @
# [[-2.85010364 -2.41719152]]
# ...
# After first @
# [[-4.18217401 -1.77261914]]
# After second @
# [[ 0.364]
#  [-0.07 ]]
# before flattening
# [[-3.57328555]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.65628577 -2.66328577]]
# After first @
# [[-2.73621759 -1.54078945]]
# After second @
# [[-0.288]
#  [-0.274]]
# before flattening
# [[-3.1638394]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.35918006 -3.44818006]]
# After first @
# [[-19.50021978   7.97280089]]
# After second @
# [[ 1.694]
#  [-0.128]]
# before flattening
# [[-32.0659969]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.46281805 -3.34581805]]
# After first @
# [[-3.87335046 -5.08640764]]
# After second @
# [[0.764]
#  [0.53 ]]
# before flattening
# [[-4.74927529]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.85628577 -2.96328577]]
# After first @
# [[-2.51589961 -4.62391589]]
# After second @
# [[0.112]
#  [0.326]]
# before flattening
# [[-3.36293794]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4
]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.70628577 -2.86328577]]
# After first @
# [[-2.32876921 -3.83111966]]
# After second @
# [[-0.188]
#  [ 0.126]]
# before flattening
# [[-3.01881595]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.00918006 -3.29818006]]
# After first @
# [[-15.07930907   5.96412297]]
# After second @
# [[ 0.994]
#  [-0.428]]
# before flattening
# [[-19.06576399]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.11281805 -3.19581805]]
# After first @
# [[-2.73069258 -4.55157945]]
# After second @
# [[0.064]
#  [0.23 ]]
# before flattening
# [[-3.39668514]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.50628577 -2.81328577]]
# After first @
# [[-1.84434944 -3.78709042]]
# After second @
# [[-0.588]
#  [ 0.026]]
# before flattening
# [[-3.38803325]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.45918006 -3.34818006]]
# After first @
# [[-22.53297105  10.7628281 ]]
# After second @
# [[ 1.894]
#  [-0.328]]
# before flattening
# [[-44.21976086]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.56281805 -3.24581805]]
# After first @
# [[-4.84100475 -3.23376743]]
# After second @
# [[0.964]
#  [0.33 ]]
# before flattening
# [[-4.82811132]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.95628577 -2.86328577]]
# After first @
# [[-3.11047837 -3.12638191]]
# After second @
# [[0.312]
#  [0.126]]
# before flattening
# [[-2.93815397]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.35918006 -3.34818006]]
# After first @
# [[-20.73896352   9.52408435]]
# After second @
# [[ 1.694]
#  [-0.328]]
# before flattening
# [[-36.97024597]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.46281805 -3.24581805]]
# After first @
# [[-4.32217688 -3.68259386]]
# After second @
# [[0.764]
#  [0.33 ]]
# before flattening
# [[-4.22780222]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.85628577 -2.86328577]]
# After first @
# [[-2.79779471 -3.40827701]]
# After second @
# [[0.112]
#  [0.126]]
# before flattening
# [[-2.87661367]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.45918006 -3.34818006]]
# After first @
# [[-22.53297105  10.7628281 ]]
# After second @
# [[ 1.894]
#  [-0.328]]
# before flattening
# [[-44.21976086]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.56281805 -3.24581805]]
# After first @
# [[-4.84100475 -3.23376743]]
# After second @
# [[0.964]
#  [0.33 ]]
# before flattening
# [[-4.82811132]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.95628577 -2.86328577]]
# After first @
# [[-3.11047837 -3.12638191]]
# After second @
# [[0.312]
#  [0.126]]
# before flattening
# [[-2.93815397]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.90918006 -3.14818006]]
# After first @
# [[-15.14341717   7.05230441]]
# After second @
# [[ 0.794]
#  [-0.728]]
# before flattening
# [[-20.43832702]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.01281805 -3.04581805]]
# After first @
# [[-2.88510436 -2.8946852 ]]
# After second @
# [[-0.136]
#  [-0.07 ]]
# before flattening
# [[-3.12046442]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.40628577 -2.66328577]]
# After first @
# [[-1.95450843 -2.24552721]]
# After second @
# [[-0.788]
#  [-0.274]]
# before flattening
# [[-3.61876216]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.40918006 -3.39818006]]
# After first @
# [[-21.01659541   9.36781449]]
# After second @
# [[ 1.794]
#  [-0.228]]
# before flattening
# [[-37.85173996]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.51281805 -3.29581805]]
# After first @
# [[-4.3571776  -4.16008753]]
# After second @
# [[0.864]
#  [0.43 ]]
# before flattening
# [[-4.64767858]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.90628577 -2.91328577]]
# After first @
# [[-2.81318899 -3.8751489 ]]
# After second @
# [[0.212]
#  [0.226]]
# before flattening
# [[-3.04594032]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.35918006 -3.44818006]]
# After first @
# [[-19.50021978   7.97280089]]
# After second @
# [[ 1.694]
#  [-0.128]]
# before flattening
# [[-32.0659969]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.46281805 -3.34581805]]
# After first @
# [[-3.87335046 -5.08640764]]
# After second @
# [[0.764]
#  [0.53 ]]
# before flattening
# [[-4.74927529]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.85628577 -2.96328577]]
# After first @
# [[-2.51589961 -4.62391589]]
# After second @
# [[0.112]
#  [0.326]]
# before flattening
# [[-3.36293794]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.35918006 -3.29818006]]
# After first @
# [[-21.3583354   10.29972608]]
# After second @
# [[ 1.694]
#  [-0.428]]
# before flattening
# [[-39.65506303]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.46281805 -3.19581805]]
# After first @
# [[-4.5465901  -2.98068697]]
# After second @
# [[0.764]
#  [0.23 ]]
# before flattening
# [[-4.17763774]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.85628577 -2.81328577]]
# After first @
# [[-2.93874226 -2.80045757]]
# After second @
# [[0.112]
#  [0.026]]
# before flattening
# [[-2.81579736]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.15918006 -3.04818006]]
# After first @
# [[-20.86717972  11.70044724]]
# After second @
# [[ 1.294]
#  [-0.928]]
# before flattening
# [[-40.08686776]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.26281805 -2.94581805]]
# After first @
# [[-4.63100043 -0.36880536]]
# After second @
# [[ 0.364]
#  [-0.27 ]]
# before flattening
# [[-4.37732787]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.65628577 -2.56328577]]
# After first @
# [[-3.01811269 -0.32515057]]
# After second @
# [[-0.288]
#  [-0.474]]
# before flattening
# [[-3.9107657]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.25918006 -3.29818006]]
# After first @
# [[-19.56432787   9.06098233]]
# After second @
# [[ 1.494]
#  [-0.428]]
# before flattening
# [[-32.8754024]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.36281805 -3.19581805]]
# After first @
# [[-4.02776224 -3.42951339]]
# After second @
# [[0.564]
#  [0.23 ]]
# before flattening
# [[-3.6950945]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.75628577 -2.81328577]]
# After first @
# [[-2.6260586  -3.08235267]]
# After second @
# [[-0.088]
#  [ 0.026]]
# before flattening
# [[-2.8229515]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-4.10918006 -3.49818006]]
# After first @
# [[-14.3958291    4.10029979]]
# After second @
# [[ 1.194]
#  [-0.028]]
# before flattening
# [[-16.72040645]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.21281805 -3.39581805]]
# After first @
# [[-2.3518676  -6.91038058]]
# After second @
# [[0.264]
#  [0.63 ]]
# before flattening
# [[-5.30099953]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.60628577 -3.01328577]]
# After first @
# [[-1.5932429  -5.93647308]]
# After second @
# [[-0.388]
#  [ 0.426]]
# before flattening
# [[-4.6046342]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.5121800625889827
# Before @
# [[-3.95918006 -3.29818006]]
# After first @
# [[-14.18230531   5.34475109]]
# After second @
# [[ 0.894]
#  [-0.428]]
# before flattening
# [[-16.84203857]]
# log(pi_k)-0.5(det(inverse_sig))
# -3.0808180541607304
# Before @
# [[-3.06281805 -3.19581805]]
# After first @
# [[-2.47127865 -4.77599266]]
# After second @
# [[-0.036]
#  [ 0.23 ]]
# before flattening
# [[-3.49265163]]
# log(pi_k)-0.5(det(inverse_sig))
# -2.800285769831183
# Before @
# [[-2.45628577 -2.81328577]]
# After first @
# [[-1.68800761 -3.92803797]]
# After second @
# [[-0.688]
#  [ 0.026]]
# before flattening
# [[-3.5948547]]
# 0.7866666666666666
